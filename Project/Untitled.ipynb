# %%
from sodapy import Socrata

client = Socrata("data.cityofchicago.org", 'TYJHLTNtRWVm0CPXyQKWEunTy')

results_police_stations = client.get("9rg7-mz9y", limit=2000)
results_police_stations
# Out:
# [{'district': '1',
#   'district_name': 'Central',
#   'address': '1718 S State St',
#   'city': 'Chicago',
#   'state': 'IL',
#   'zip': '60616',
#   'website': 'http://home.chicagopolice.org/community/districts/1st-district-central/',
#   'phone': '312-745-4290',
#   'fax': '312-745-3694',
#   'tty': '312-745-3693',
#   'x_coordinate': '1176569.052',
#   'y_coordinate': '1891771.704',
#   'latitude': '41.85837259',
#   'longitude': '-87.62735617',
#   'location': {'type': 'Point', 'coordinates': [-87.627356171, 41.8583725929]},
#   ':@computed_region_rpca_8um6': '40',
#   ':@computed_region_vrxf_vc4k': '34',
#   ':@computed_region_6mkv_f3dw': '21194',
#   ':@computed_region_bdys_3d7i': '330',
#   ':@computed_region_43wa_7qmu': '9',
#   ':@computed_region_awaf_s7ux': '12'},
#  {'district': '6',
#   'district_name': 'Gresham',
#   'address': '7808 S Halsted St',
#   'city': 'Chicago',
#   'state': 'IL',
#   'zip': '60620',
# ...
